# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros
alpha = 0.10
alpha_2 = alpha / 2
z_crit = 1.645  # valor z tal que P(Z > 1.645) = 0.05 en la Normal estándar

# Generamos un rango de valores para la variable 'z'
x = np.linspace(-3, 3, 500)
y = norm.pdf(x)  # f(z) = pdf de la Normal(0,1)

# Creamos la figura
plt.figure(figsize=(8, 5))

# Dibujamos la curva de densidad
plt.plot(x, y, color='blue', label='Densidad $N(0,1)$')

# Sombreamos las colas:
#   - Cola izquierda: z < -z_crit
#   - Cola derecha: z > +z_crit
x_left = np.linspace(-3, -z_crit, 200)
y_left = norm.pdf(x_left)
plt.fill_between(x_left, y_left, color='cyan', alpha=0.5)

x_right = np.linspace(z_crit, 3, 200)
y_right = norm.pdf(x_right)
plt.fill_between(x_right, y_right, color='cyan', alpha=0.5)

# Trazamos líneas verticales punteadas en z = ±z_crit
plt.vlines([-z_crit, z_crit], 0, 0.1, color='blue')
plt.axhline(y=0, color="black", linewidth=1.5)

# Etiquetas para z_crit
plt.text(-z_crit, -0.01, r"$-z_{0.95}=-1.645$", 
         ha='center', va='top', fontsize=10, color='blue')
plt.text(z_crit, -0.01, r"$z_{0.95}=1.645$", 
         ha='center', va='top', fontsize=10, color='blue')

# Agregamos un texto indicando alpha/2 en cada cola
# (opcionalmente, con flechas o simplemente un texto cercano)
plt.text(-2.7, 0.06, r"$\frac{\alpha}{2}=0.05$", 
         ha='center', va='bottom', fontsize=9, color='blue')
plt.text(2.7, 0.06, r"$\frac{\alpha}{2}=0.05$", 
         ha='center', va='bottom', fontsize=9, color='blue')

# Etiqueta central que muestra 1 - alpha
plt.text(0, 0.25, r"$1 - \alpha = 0.90$", color="blue", 
         ha='center', va='bottom', fontsize=11)

# Etiquetamos la función
plt.text(0, 0.42, r"$\mathcal{N}(0,1)$",
         ha='center', va='bottom', fontsize=11, color='blue')

# Ajustes finales del gráfico
plt.ylim(0, 0.45)
plt.xlim(-3, 3)
plt.grid(False)
plt.xticks([])  # Quitar valores del eje x
plt.yticks([])  # Quitar valores del eje y
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().set_facecolor("none")
plt.gca().patch.set_facecolor("none")
plt.gcf().patch.set_facecolor("none")

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# Parámetros
alpha = 0.10
alpha_2 = alpha / 2
df = 10  # Grados de libertad para t-Student
t_crit = t.ppf(1 - alpha_2, df)  # Valor crítico t para alpha/2

# Generamos un rango de valores para la distribución t
x = np.linspace(-4, 4, 500)
y = t.pdf(x, df)  # Función de densidad de la distribución t

# Creamos la figura
plt.figure(figsize=(8, 5))

# Dibujamos la curva de densidad
plt.plot(x, y, color='blue', label='Distribución $t$ de Student')

# Sombreamos el área central entre -t_crit y t_crit
x_fill_1 = np.linspace(-4, -t_crit, 200)
y_fill_1 = t.pdf(x_fill_1, df)
plt.fill_between(x_fill_1, y_fill_1, color='blue', alpha=0.2)

x_fill_2 = np.linspace(t_crit, 4, 200)
y_fill_2 = t.pdf(x_fill_2, df)
plt.fill_between(x_fill_2, y_fill_2, color='blue', alpha=0.2)

# Trazamos líneas verticales punteadas en ±t_crit
plt.vlines([-t_crit, t_crit], 0, 0.08, color='blue')
plt.vlines(0, 0, 0.39, color="blue")
# plt.hlines(y=0.08, xmin=-t_crit, xmax=t_crit, color="blue", linestyle="--")

# Etiquetas en -t_crit y t_crit
plt.text(-t_crit, -0.02, r"$-t_{n_A+n_B-2},1-\frac{\alpha}{2}}$",
         ha='center', fontsize=10, color='blue')
plt.text(t_crit, -0.02, r"$t_{n_A+n_B-2},1-\frac{\alpha}{2}}$",
         ha='center', fontsize=10, color='blue')

# Etiqueta central para 1-alpha
plt.text(0, 0.2, r"$1-\alpha$", ha='center', fontsize=12, color="blue")

# Etiquetas en las colas para alpha/2
plt.text(-3.5, 0.05, r"$-\frac{\alpha}{2}$", ha='center', fontsize=10, color='blue')
plt.text(3.5, 0.05, r"$\frac{\alpha}{2}$", ha='center', fontsize=10, color='blue')

# Etiqueta del ancho del intervalo
# plt.annotate("", xy=(-4, -0.05), xytext=(4, -0.05),
#              arrowprops=dict(arrowstyle='<->', color='black'))
# plt.text(0, -0.1, r"$1-\frac{\alpha}{2}$", ha='center', fontsize=10)

# Ajustes finales del gráfico
plt.ylim(-0.15, 0.4)
plt.xlim(-4, 4)
plt.xticks([])  # Sin valores en el eje x
plt.yticks([])  # Sin valores en el eje y
plt.axhline(0, color='black', linewidth=0.8)  # Eje horizontal
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().set_facecolor("none")
plt.gca().patch.set_facecolor("none")
plt.gcf().patch.set_facecolor("none")
# Out:
# Error in callback <function _draw_all_if_interactive at 0x0000026481288160> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
#    1904     with self._idle_draw_cntx():
# -> 1905         self.draw(*args, **kwargs)
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\backends\backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     384 # Acquire a lock on the shared font cache.
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#     390     super().draw()
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\axes\_base.py:3137, in _AxesBase.draw(self, renderer)
#    3134 if artists_rasterized:
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#    3141 self.stale = False
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\text.py:751, in Text.draw(self, renderer)
#     748 renderer.open_group('text', self.get_gid())
#     750 with self._cm_set(text=self._get_wrapped_text()):
# --> 751     bbox, info, descent = self._get_layout(renderer)
#     752     trans = self.get_transform()
#     754     # don't use self.get_position here, which refers to text
#     755     # position in Text:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\text.py:381, in Text._get_layout(self, renderer)
#     379 clean_line, ismath = self._preprocess_math(line)
#     380 if clean_line:
# --> 381     w, h, d = _get_text_metrics_with_cache(
#     382         renderer, clean_line, self._fontproperties,
#     383         ismath=ismath, dpi=self.figure.dpi)
#     384 else:
#     385     w = h = d = 0
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\backends\backend_agg.py:216, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     212     return super().get_text_width_height_descent(s, prop, ismath)
#     214 if ismath:
#     215     ox, oy, width, height, descent, font_image = \
# --> 216         self.mathtext_parser.parse(s, self.dpi, prop)
#     217     return width, height, descent
#     219 font = self._prepare_font(prop)
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\mathtext.py:79, in MathTextParser.parse(self, s, dpi, prop, antialiased)
#      77 prop = prop.copy() if prop is not None else None
#      78 antialiased = mpl._val_or_rc(antialiased, 'text.antialiased')
# ---> 79 return self._parse_cached(s, dpi, prop, antialiased)
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\mathtext.py:100, in MathTextParser._parse_cached(self, s, dpi, prop, antialiased)
#      97 if self._parser is None:  # Cache the parser globally.
#      98     self.__class__._parser = _mathtext.Parser()
# --> 100 box = self._parser.parse(s, fontset, fontsize, dpi)
#     101 output = _mathtext.ship(box)
#     102 if self._output_type == "vector":
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\_mathtext.py:2173, in Parser.parse(self, s, fonts_object, fontsize, dpi)
#    2170     result = self._expression.parseString(s)
#    2171 except ParseBaseException as err:
#    2172     # explain becomes a plain method on pyparsing 3 (err.explain(0)).
# -> 2173     raise ValueError("\n" + ParseException.explain(err, 0)) from None
#    2174 self._state_stack = []
#    2175 self._in_subscript_or_superscript = False
#
# ValueError:
# $-t_{n_A+n_B-2},1-\frac{\alpha}{2}}$
# ^
# ParseException: Expected end of text, found '$'  (at char 0), (line:1, col:1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\.conda\envs\optim-2\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~\.conda\envs\optim-2\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\backend_bases.py:2175, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2172     # we do this instead of `self.figure.draw_without_rendering`
#    2173     # so that we can inject the orientation
#    2174     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2175         self.figure.draw(renderer)
#    2176 if bbox_inches:
#    2177     if bbox_inches == "tight":
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\axes\_base.py:3137, in _AxesBase.draw(self, renderer)
#    3134 if artists_rasterized:
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#    3141 self.stale = False
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\text.py:751, in Text.draw(self, renderer)
#     748 renderer.open_group('text', self.get_gid())
#     750 with self._cm_set(text=self._get_wrapped_text()):
# --> 751     bbox, info, descent = self._get_layout(renderer)
#     752     trans = self.get_transform()
#     754     # don't use self.get_position here, which refers to text
#     755     # position in Text:
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\text.py:381, in Text._get_layout(self, renderer)
#     379 clean_line, ismath = self._preprocess_math(line)
#     380 if clean_line:
# --> 381     w, h, d = _get_text_metrics_with_cache(
#     382         renderer, clean_line, self._fontproperties,
#     383         ismath=ismath, dpi=self.figure.dpi)
#     384 else:
#     385     w = h = d = 0
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\backends\backend_agg.py:216, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     212     return super().get_text_width_height_descent(s, prop, ismath)
#     214 if ismath:
#     215     ox, oy, width, height, descent, font_image = \
# --> 216         self.mathtext_parser.parse(s, self.dpi, prop)
#     217     return width, height, descent
#     219 font = self._prepare_font(prop)
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\mathtext.py:79, in MathTextParser.parse(self, s, dpi, prop, antialiased)
#      77 prop = prop.copy() if prop is not None else None
#      78 antialiased = mpl._val_or_rc(antialiased, 'text.antialiased')
# ---> 79 return self._parse_cached(s, dpi, prop, antialiased)
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\mathtext.py:100, in MathTextParser._parse_cached(self, s, dpi, prop, antialiased)
#      97 if self._parser is None:  # Cache the parser globally.
#      98     self.__class__._parser = _mathtext.Parser()
# --> 100 box = self._parser.parse(s, fontset, fontsize, dpi)
#     101 output = _mathtext.ship(box)
#     102 if self._output_type == "vector":
#
# File ~\.conda\envs\optim-2\lib\site-packages\matplotlib\_mathtext.py:2173, in Parser.parse(self, s, fonts_object, fontsize, dpi)
#    2170     result = self._expression.parseString(s)
#    2171 except ParseBaseException as err:
#    2172     # explain becomes a plain method on pyparsing 3 (err.explain(0)).
# -> 2173     raise ValueError("\n" + ParseException.explain(err, 0)) from None
#    2174 self._state_stack = []
#    2175 self._in_subscript_or_superscript = False
#
# ValueError:
# $-t_{n_A+n_B-2},1-\frac{\alpha}{2}}$
# ^
# ParseException: Expected end of text, found '$'  (at char 0), (line:1, col:1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Parámetros
alpha = 0.10
alpha_2 = alpha / 2
df = 10  # Grados de libertad para chi-cuadrado

# Valores críticos para la distribución chi-cuadrado
chi2_lower = chi2.ppf(alpha_2, df)  # Valor crítico inferior
chi2_upper = chi2.ppf(1 - alpha_2, df)  # Valor crítico superior

# Generamos un rango de valores para la distribución chi-cuadrado
x = np.linspace(0, chi2.ppf(0.995, df), 500)
y = chi2.pdf(x, df)  # Función de densidad de la distribución chi-cuadrado

# Creamos la figura
plt.figure(figsize=(8, 5))

# Dibujamos la curva de densidad
plt.plot(x, y, color='blue', label=r'Distribución $\chi^2$')

# Sombreamos el área central entre chi2_lower y chi2_upper
x_fill = np.linspace(chi2_upper, 25, 200)
y_fill = chi2.pdf(x_fill, df)
plt.fill_between(x_fill, y_fill, color='cyan', alpha=0.5)
x_fill_2 = np.linspace(0, chi2_lower, 200)
y_fill_2 = chi2.pdf(x_fill_2, df)
plt.fill_between(x_fill_2, y_fill_2, color='cyan', alpha=0.5)
plt.vlines(chi2_upper, 0, 0.015, color='blue', linestyle='--')
plt.vlines(chi2_lower, 0, 0.0425, color='blue', linestyle='--')

# Etiquetas en los valores críticos
plt.text(chi2_lower, -0.01, r"$\chi^2_{n-1, \frac{\alpha}{2}}$", 
         ha='center', fontsize=10, color='blue')
plt.text(chi2_upper, -0.01, r"$\chi^2_{n-1, 1-\frac{\alpha}{2}}$", 
         ha='center', fontsize=10, color='blue')

# Etiqueta central para 1-alpha
plt.text((chi2_lower + chi2_upper) / 2, max(y), r"$1-\alpha$", color="blue",
         ha='center', fontsize=12)

plt.text(2, 0.02, r"$-\frac{\alpha}{2}$", ha='center', fontsize=10, color='blue')
plt.text(22.5, 0.02, r"$\frac{\alpha}{2}$", ha='center', fontsize=10, color='blue')

# Ajustes finales
plt.xticks([])  # Sin valores en el eje x
plt.yticks([]) 
plt.ylim(0, 0.1)
plt.xlim(-1, 25)
plt.axhline(0, color="black", linewidth=1.5)
plt.axvline(0, color="black", linewidth=1.5)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().set_facecolor("none")
plt.gca().patch.set_facecolor("none")
plt.gcf().patch.set_facecolor("none")

# %%
 # Reimportamos las bibliotecas necesarias debido al reinicio del entorno
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Parámetros
alpha = 0.10
alpha_2 = alpha / 2
df1 = 10  # Grados de libertad del numerador
df2 = 12  # Grados de libertad del denominador

# Valores críticos para la distribución F
f_lower = f.ppf(alpha_2, df1, df2)  # Valor crítico inferior
f_upper = f.ppf(1 - alpha_2, df1, df2)  # Valor crítico superior

# Generamos un rango de valores para la distribución F
x = np.linspace(0, f.ppf(0.995, df1, df2), 500)
y = f.pdf(x, df1, df2)  # Función de densidad de la distribución F

# Creamos la figura
plt.figure(figsize=(8, 5))

# Dibujamos la curva de densidad
plt.plot(x, y, color='blue', label=r'Distribución $F$')

# Sombreamos el área central entre f_lower y f_upper
x_fill = np.linspace(f_upper, f.ppf(0.995, df1, df2), 200)
y_fill = f.pdf(x_fill, df1, df2)
plt.fill_between(x_fill, y_fill, color='cyan', alpha=0.7)

x_fill_2 = np.linspace(0, f_lower, 200)
y_fill_2 = f.pdf(x_fill_2, df1, df2)
plt.fill_between(x_fill_2, y_fill_2, color='cyan', alpha=0.7)

# Trazamos líneas verticales en los valores críticos
plt.vlines(f_lower, 0, 0.45, color='blue', linestyle='--')
plt.vlines(f_upper, 0, 0.065, color='blue', linestyle='--')

# Etiquetas en los valores críticos
plt.text(f_lower, -0.04, r"$F_{n, m, \frac{\alpha}{2}}$", 
         ha='center', fontsize=10, color='blue')
plt.text(f_upper, -0.04, r"$F_{n, m, 1-\frac{\alpha}{2}}$", 
         ha='center', fontsize=10, color='blue')

# Etiqueta central para 1-alpha
plt.text((f_lower + f_upper) / 2, max(y) * 0.2, r"$1-\alpha$", 
         ha='center', fontsize=12, color="blue")

# plt.text((f_lower + f_upper) / 2, max(y), r"$F_{n_X-1,n_Y-1}$", 
#          ha='center', fontsize=12, color="blue")

# Ajustes finales del gráfico
plt.ylim(-0.05, max(y) * 1.1)
plt.xlim(-0.05, f.ppf(0.995, df1, df2))
plt.axhline(0, color="black", linewidth=1.5)
plt.axvline(0, color="black", linewidth=1.5)
plt.xticks([])  # Sin valores en el eje x
plt.yticks([]) 
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().set_facecolor("none")
plt.gca().patch.set_facecolor("none")
plt.gcf().patch.set_facecolor("none")

# %%
from scipy.stats import f

# Parámetros de la función F de Snedecor
df1 = 24  # grados de libertad del numerador
df2 = 29  # grados de libertad del denominador
alpha = 0.05

# Calcular los valores críticos
print(round(f.ppf(1 - alpha/2, df1, df2), 4))
print(round(f.ppf(alpha / 2, df1, df2), 4))
# Out:
# 2.154
# 0.451
