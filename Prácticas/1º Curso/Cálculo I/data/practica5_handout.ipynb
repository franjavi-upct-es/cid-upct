# %% [markdown]
# # Práctica 5

# %% [markdown]
# Contenidos: Series de potencias y series de Fourier.

# %% [markdown]
# Bibliografía:  https://pythonnumericalmethods.berkeley.edu/notebooks/Index.html
#
#               J. M. Stewart, Python for scientists. Cambridge University Press.

# %% [markdown]
# ## Series de potencias

# %% [markdown]
# Con el comando de Sympy sy.series podemos calcular el desarrollo en serie de
# potencias de una función. Veamos algunos ejemplos. Antes cargaremos los módulos
# que necesitaremos.

# %%
import numpy as np
import sympy as sy
from matplotlib import pyplot as plt
from scipy.integrate import simpson

# %%
x = sy.symbols('x')
funcion1 = sy.exp(sy.sin(x))
funcion1
# Out:
# exp(sin(x))

# %%
x = sy.symbols('x')
f1 = sy.fps(sy.exp(x))
f2 = sy.fps(sy.sin(x))

# %%
f1
# Out:
# FormalPowerSeries(exp(x), x, 0, 1, (SeqFormula(Piecewise((1/factorial(_k), Eq(Mod(_k, 1), 0)), (0, True)), (_k, 1, oo)), SeqFormula(x**_k, (_k, 0, oo)), 1))

# %%
f2
# Out:
# FormalPowerSeries(sin(x), x, 0, 1, (SeqFormula(Piecewise(((-1/4)**(_k/2 - 1/2)/(RisingFactorial(3/2, _k/2 - 1/2)*factorial(_k/2 - 1/2)), Eq(Mod(_k, 2), 1)), (0, True)), (_k, 2, oo)), SeqFormula(x**_k, (_k, 0, oo)), x))

# %%
f1.truncate(n=8)
# Out:
# 1 + x + x**2/2 + x**3/6 + x**4/24 + x**5/120 + x**6/720 + x**7/5040 + O(x**8)

# %% [markdown]
# Para componer funciones disponemos del comando compose.

# %%
f1.compose(f2,x).truncate()
# Out:
# 1 + x + x**2/2 - x**4/8 - x**5/15 + O(x**6)

# %% [markdown]
# ## Series de Fourier

# %% [markdown]
# Podemos utilizar diferentes recursos para trabajar con series de Fourier con
# Python. Una opción es definir nuestras propias funciones.

# %% [markdown]
# Recuerda:
# $$f(x)=\frac{A_0}{2}+\sum_{n=1}^\infty A_n\, \cos(nx)+B_n\,\sin(nx).$$
# Siendo
# $$A_n=\frac{1}{\pi}\int_{-\pi}^{\pi} f(x) \cos(nx)\,dx,$$
# $$B_n=\frac{1}{\pi}\int_{-\pi}^{\pi} f(x)\sin(nx)\,dx.$$

# %%
def my_fourier_coef(f,n):
    x = np.linspace(-np.pi, np.pi, 1001)
    y1 = f(x)*np.cos(n*x)
    y2 = f(x)*np.sin(n*x)
    return([1/np.pi*simpson(y1,x), 1/np.pi*simpson(y2,x)])

# %%
def f(x):
    return(np.sin(np.exp(x)))

# %%
def plot_results(f, N):
    x = np.linspace(-np.pi, np.pi, 1000)
    [A0, B0] = my_fourier_coef(f, 0)
    y = A0*np.ones(len(x))/2
    for n in range (1, N):
        [An, Bn] = my_fourier_coef(f, n)
        y += An*np.cos(n*x)+Bn*np.sin(n*x)
    plt.figure(figsize= (10,6))
    plt.plot(x, f(x), label = 'analítica')
    plt.plot(x,y, label = 'aproximación')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid()
    plt.legend()
    plt.title(f'{N}-ésimo aproximación de Fourier')
    plt.show()

# %%
plot_results(f, 2)

# %% [markdown]
# Si aumentamos el orden de la serie:

# %%
plot_results(f,20)

# %% [markdown]
# Veamos otros ejemplos

# %%
f = lambda x: np.mod(x, np.pi/2)

# %% [markdown]
# Utiliza la función anterior y representa su aproximación de Fourier de orden 5 y
# orden 20. Repite el procedimiento con la función:

# %%
f2 = lambda x: (x > -np.pi/2) & (x < np.pi/2)

# %%
plt.plot(x,f2(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# g:\Mi unidad\franjavi-fc\Prácticas\Cálculo I\data\practica5_handout.ipynb Cell 27 line 1
# ----> <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/franjavi-fc/Pr%C3%A1cticas/C%C3%A1lculo%20I/data/practica5_handout.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> plt.plot(x,f2(x))
#
# File c:\Users\fcoja\anaconda3\lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File c:\Users\fcoja\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1723, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
# -> 1723     self.add_line(line)
#    1724 if scalex:
#    1725     self._request_autoscale_view("x")
#
# File c:\Users\fcoja\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2309, in _AxesBase.add_line(self, line)
#    2306 if line.get_clip_path() is None:
#    2307     line.set_clip_path(self.patch)
# -> 2309 self._update_line_limits(line)
#    2310 if not line.get_label():
#    2311     line.set_label(f'_child{len(self._children)}')
#
# File c:\Users\fcoja\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2332, in _AxesBase._update_line_limits(self, line)
#    2328 def _update_line_limits(self, line):
#    2329     """
#    2330     Figures out the data limit of the given line, updating self.dataLim.
#    2331     """
# -> 2332     path = line.get_path()
#    2333     if path.vertices.size == 0:
#    2334         return
#
# File c:\Users\fcoja\anaconda3\lib\site-packages\matplotlib\lines.py:1032, in Line2D.get_path(self)
#    1030 """Return the `~matplotlib.path.Path` associated with this line."""
#    1031 if self._invalidy or self._invalidx:
# -> 1032     self.recache()
#    1033 return self._path
#
# File c:\Users\fcoja\anaconda3\lib\site-packages\matplotlib\lines.py:669, in Line2D.recache(self, always)
#     667 if always or self._invalidx:
#     668     xconv = self.convert_xunits(self._xorig)
# --> 669     x = _to_unmasked_float_array(xconv).ravel()
#     670 else:
#     671     x = self._x
#
# File c:\Users\fcoja\anaconda3\lib\site-packages\matplotlib\cbook.py:1345, in _to_unmasked_float_array(x)
#    1343     return np.ma.asarray(x, float).filled(np.nan)
#    1344 else:
# -> 1345     return np.asarray(x, float)
#
# File c:\Users\fcoja\anaconda3\lib\site-packages\sympy\core\expr.py:351, in Expr.__float__(self)
#     349 if result.is_number and result.as_real_imag()[1]:
#     350     raise TypeError("Cannot convert complex to float")
# --> 351 raise TypeError("Cannot convert expression to float")
#
# TypeError: Cannot convert expression to float

# %% [markdown]
# La otra posibilidad nos la proporciona Sympy que nos ofrece la opción de
# calcular directamente con el comando que ofrece la serie de Fourier.
# Veamos un ejemplo

# %%
x = sy.symbols('x')
serie1 = sy.fourier_series(x**2, (x, -sy.pi, sy.pi))

# %%
serie1
# Out:
# FourierSeries(x**2, (x, -pi, pi), (pi**2/3, SeqFormula(Piecewise((2*pi**2*sin(_n*pi)/_n + 4*pi*cos(_n*pi)/_n**2 - 4*sin(_n*pi)/_n**3, (_n > -oo) & (_n < oo) & Ne(_n, 0)), (2*pi**3/3, True))*cos(_n*x)/pi, (_n, 1, oo)), SeqFormula(0, (_k, 1, oo))))

# %%
serie1.truncate()
# Out:
# -4*cos(x) + cos(2*x) + pi**2/3

# %%
serie2 =sy.fourier_series(sy.sin(sy.exp(x)),(x,-sy.pi,sy.pi))

# %%
serie2.truncate(n=2)
# Out:
# sin(x)*Integral(sin(x)*sin(exp(x)), (x, -pi, pi))/pi + cos(x)*Integral(sin(exp(x))*cos(x), (x, -pi, pi))/pi + Integral(sin(exp(x)), (x, -pi, pi))/(2*pi)
