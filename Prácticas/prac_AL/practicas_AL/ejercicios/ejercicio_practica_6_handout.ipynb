# %% [markdown]
# # Práctica 6: Ejercicio para entregar.
# ## Matrices spase. Manipulación de matrices desde ficheros de datos

# %% [markdown]
# Introduce una matriz aleatoria y sparse $A$ de $10$ filas y $5$ columnas y cuya sparsity sea $0.8$.

# %%
import numpy as np
from scipy.sparse import csr_matrix, csc_matrix
from scipy import sparse

# %%
# Completar aquí
A = sparse.random(10, 5, density=0.2)
print(f"A = \n {A}")
# --------------------
# Out:
# A =
#    (3, 1)	0.7198494736733119
#   (9, 1)	0.4573353888242274
#   (3, 0)	0.34349952596876443
#   (7, 2)	0.9671362105564743
#   (8, 1)	0.35615185704411556
#   (5, 3)	0.30499638739166834
#   (6, 2)	0.26683948030723303
#   (1, 0)	0.853229790790128
#   (7, 0)	0.30477406760862114
#   (9, 0)	0.7996291477221281

# %% [markdown]
# Introduce otra matriz aleatoria y sparse $B$ de $5$ filas y $10$ columnas y cuya sparsity sea $0.7$.

# %%
# Completar aquí
B = sparse.random(5, 10, density=0.3)
print(f"B = \n {B}")
# --------------------
# Out:
# B =
#    (4, 5)	0.3848257190760379
#   (0, 5)	0.9143461783226053
#   (0, 2)	0.9171044003616534
#   (4, 8)	0.6944817905965867
#   (0, 7)	0.5276346183424602
#   (1, 0)	0.3452693531299875
#   (4, 2)	0.8636116636904461
#   (3, 5)	0.05353461826052419
#   (4, 4)	0.0917359048442038
#   (3, 8)	0.4985508065060362
#   (4, 6)	0.3064924877990979
#   (4, 9)	0.6366961820397672
#   (0, 3)	0.7682868919040512
#   (4, 0)	0.7207177504717902
#   (3, 0)	0.9427196446570494

# %% [markdown]
# Calcula el producto usual (dot product) de $A$ y $B$. Sea $C$ la matriz resultante.

# %%
# Completar aquí
C = A.dot(B)
print(f"C = \n {C}")
# --------------------
# Out:
# C =
#    (1, 7)	0.4501935750219663
#   (1, 5)	0.7801473984399496
#   (1, 3)	0.6555252640460912
#   (1, 2)	0.7825007956532792
#   (3, 0)	0.24854196212614638
#   (3, 7)	0.181242241285345
#   (3, 5)	0.3140774788251663
#   (3, 3)	0.26390618317705694
#   (3, 2)	0.3150249267880959
#   (5, 8)	0.1520561949155437
#   (5, 5)	0.016327865169851918
#   (5, 0)	0.2875260859435574
#   (7, 7)	0.16080934884335396
#   (7, 5)	0.27866900396977806
#   (7, 3)	0.23415392113598268
#   (7, 2)	0.2795096385199865
#   (8, 0)	0.12296832129766556
#   (9, 0)	0.15790389386279233
#   (9, 7)	0.42191202017387175
#   (9, 5)	0.7311378552950899
#   (9, 3)	0.6143445925793193
#   (9, 2)	0.7333434100334023

# %% [markdown]
# 1) Graba la matriz $C$ en tu carpeta **data**, en formato .npz y con el nombre C.npz
#
# 2) Transforma la matriz $C$ anterior de formato sparse a dense y llama $D$ a la nueva matriz
#
# 3) Calcula la sparsity de la matriz $D$

# %%
# Completar aquí
# 1.
sparse.save_npz('../data/C.npz', C)
# 2.
D = C.todense()
# 3.
def sparsity(D):
    sparsi = 1.0 - np.count_nonzero(D) / D.size
    return sparsi

print(f"sparsity(D) = {sparsity(D)}")
# --------------------
# Out:
# sparsity(D) = 0.78

# %% [markdown]
# Carga la matriz C.npz, llama $CC$ a la matriz que has cargado e imprímela por pantalla

# %%
# Completar aquí
CC = sparse.load_npz("../data/C.npz")
print(CC)
# --------------------
# Out:
#   (1, 7)	0.4501935750219663
#   (1, 5)	0.7801473984399496
#   (1, 3)	0.6555252640460912
#   (1, 2)	0.7825007956532792
#   (3, 0)	0.24854196212614638
#   (3, 7)	0.181242241285345
#   (3, 5)	0.3140774788251663
#   (3, 3)	0.26390618317705694
#   (3, 2)	0.3150249267880959
#   (5, 8)	0.1520561949155437
#   (5, 5)	0.016327865169851918
#   (5, 0)	0.2875260859435574
#   (7, 7)	0.16080934884335396
#   (7, 5)	0.27866900396977806
#   (7, 3)	0.23415392113598268
#   (7, 2)	0.2795096385199865
#   (8, 0)	0.12296832129766556
#   (9, 0)	0.15790389386279233
#   (9, 7)	0.42191202017387175
#   (9, 5)	0.7311378552950899
#   (9, 3)	0.6143445925793193
#   (9, 2)	0.7333434100334023
