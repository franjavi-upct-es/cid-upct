# %%
# !python -m pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.0/670.0 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 29.1 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# Conexión al servidor MongoDB
client = MongoClient("mongodb+srv://pyros05:Fj081212@cluster0.bfjczeu.mongodb.net/")

# Acceso a la base de datos 'juegos'
db = client['juegos']

# Inserción de documentos en la colección 'juegos' de la base de datos 'juegos'
db.juegos.insert_many([
    {
        "_id": 1,
        "titulo": "The Legend of Zelda: Breath of the Wild",
        "desarrollador_id": 101,
        "año": 2017,
        "plataforma": ['Switch', 'Wii U']
    },
    {
        "_id": 2,
        "titulo": "Super Mario Odyssey",
        "desarrollador_id": 101,
        "año": 2017,
        "plataforma": ['Switch']
    },
    {
        "_id": 3,
        "titulo": "God of War",
        "desarrollador_id": 102,
        "año": 2018,
        "plataforma": ['PS4']
    }
])
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-7-1a67602f6018> in <cell line: 10>()
#       8
#       9 # Inserción de documentos en la colección 'juegos' de la base de datos 'juegos'
# ---> 10 db.juegos.insert_many([
#      11     {
#      12         "_id": 1,
#
# /usr/local/lib/python3.10/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     740         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     741         blk.ops = list(gen())
# ...
