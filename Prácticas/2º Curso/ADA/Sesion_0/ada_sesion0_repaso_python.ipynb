# %% [markdown]
# # Análisis y Diseño de Algoritmos - Curso 24/25

# %%
import sys, subprocess

modulos_requeridos = ['numpy', 'matplotlib', 'seaborn']
for modulo in modulos_requeridos:
    if subprocess.call([sys.executable, '-m', 'pip', 'show', modulo], 
                       stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL):
        print(f"Instalando el módulo {modulo}")
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', modulo])
# Out:
# Instalando el módulo numpy
# Instalando el módulo matplotlib
# Instalando el módulo seaborn

# %% [markdown]
# ## Boletín 0 - Taller de Programación en Python
#
# En esta sesión vamos a repasar algunos conceptos básicos de programación en Python que van ser de utilidad para el desarrollo de las prácticas de la asignatura.

# %% [markdown]
# ### 1. Manejo y creación de listas
#
# La creación de una lista en Python se pude realizar de forma explícita indicando los elementos.

# %%
mi_lista = [1, 2, 3, 4, 5]
mi_lista
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Podemos acceder a un determinado elementos indicando su índice en la lista.

# %%
print(mi_lista[0])
# Out:
# 1

# %%
print(mi_lista[-1])
# Out:
# 5

# %%
mi_lista[0] = 10
print(mi_lista)
# Out:
# [10, 2, 3, 4, 5]

# %% [markdown]
# De igual modo, podemos acceder a un rango de posiciones en la lista indicando la `posicion_inicial:posicion_final+1`
#
# Si quueremos acceder a los elementos en las posiciones 1 y 2 de `mi_lista` deberemos ejecutar el siguiente código.

# %%
print(mi_lista[1:3])
# Out:
# [2, 3]

# %% [markdown]
# También es posible no indicar un límite inferior (o superior).
#
# Así, el siguiente código recuperaría los elementos en las posiciones 0, 1 y 2 de la lista.

# %%
print(mi_lista[:3])
# Out:
# [10, 2, 3]

# %% [markdown]
# Del mismo modo, podemos usar posiciones negativas para indexsar desde el final de la lista.
#
# La siguiente instruccion recupera todos los elementos de `mi_lista` salvo el último.

# %%
print(mi_lista[:-1])
# Out:
# [10, 2, 3, 4]

# %% [markdown]
# #### Inserción de elementos
#
# Existen varias formas de insertar elementos en una lista ya existente.
#
# Con `.append` añadimos un determinado valor al final de una lista dada.

# %%
mi_lista.append(6)
print(mi_lista)
# Out:
# [10, 2, 3, 4, 5, 6]

# %% [markdown]
# Con el `.insert` podemos especificar la posición en la que queremos insertar un elemento.

# %%
mi_lista.insert(2,44)
mi_lista
# Out:
# [10, 2, 44, 3, 4, 5, 6]

# %% [markdown]
# Hay que tener en cuenta que si con `.insert`  especificamos un índice negativo, se insertará en la posición contando desde atrás.

# %%
mi_lista.insert(-3,16)
mi_lista
# Out:
# [10, 2, 44, 3, 16, 4, 5, 6]

# %% [markdown]
# Del mismo modo si indicamos un índice mayor al tamaño de la lista, el elemento se insertará al final de la misma.
#
# Actualmente nuestra lista contiene 8 elementos, si intentamos insertar el valor 66 en la posición 12 veremos que, en realidad, añade al final de la misma.

# %%
print(len(mi_lista))
mi_lista.insert(12,66)
mi_lista
# Out:
# 8
# [10, 2, 44, 3, 16, 4, 5, 6, 66]

# %% [markdown]
# #### Borrado de elementos
#
# Al igual que ocurre con la inserción, existen diferentes formas de eliminar un objeto de una lista.

# %% [markdown]
# Con `.remove` borramos un valor específico de la lista. Así, si quisieramos eliminar todos los valores *66* de la `mi_lista` deberíamos ejecutar la siguiente instrucción.

# %%
mi_lista.remove(66)
print(mi_lista)
# Out:
# [10, 2, 44, 3, 16, 4, 5, 6]

# %% [markdown]
# Con `.pop` borramos el elemento en un determinado índice.

# %%
mi_lista.pop(2)
print(mi_lista)
# Out:
# [10, 2, 3, 16, 4, 5, 6]

# %% [markdown]
# Si no especificamos indice borra el último elemento

# %%
mi_lista.pop()
print(mi_lista)
# Out:
# [10, 2, 3, 16, 4, 5]

# %% [markdown]
# #### Concatenación de listas

# %%
nueva_lista = mi_lista + [77, 88, 99]
print(nueva_lista)
# Out:
# [10, 2, 3, 16, 4, 5, 77, 88, 99]

# %% [markdown]
# #### Búsquedas en listas

# %%
print(2 in mi_lista)
# Out:
# True

# %% [markdown]
# Con el método `.index` podemos obtener el/los indices en los que aparece un valor determinado.
#
# Si quisieramos saber en qué posición se encuentra el valor 16 en `mi_lista` deberíamos ejecutar el siguiente comando

# %%
print(mi_lista.index(16))
# Out:
# 3

# %% [markdown]
# Si intentamos buscar un elemento que no se encuentra en la lista obtendremos una excepción del tipo `ValueError`

# %%
# print(mi_lista.index(987))

# %% [markdown]
# #### Ordenación de listas

# %%
mi_lista.sort()
print(mi_lista)
# Out:
# [2, 3, 4, 5, 10, 16]

# %%
mi_lista.reverse()
print(mi_lista)
# Out:
# [16, 10, 5, 4, 3, 2]

# %% [markdown]
# #### List comprehension
#
# Con esta herramienta podemos sintetizar de forma sencilla en el caso de que queramos realizar el mismo tratamiento a todos los elementos de un array.

# %%
squares = [x**2 for x in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
mi_lista_alcuadrado = [n**2 for n in mi_lista]
print(mi_lista_alcuadrado)
# Out:
# [256, 100, 25, 16, 9, 4]

# %% [markdown]
# #### Uso de  `numpy` para el manejo de listas
#
# Para instalar numpy deberemos ejecutar
#
# `pip install numpy`

# %% [markdown]
# Podemos crear arrays con `numpy` de múltiples formas.

# %%
import numpy as np

# Crear un array de una lista
my_array = np.array(mi_lista_alcuadrado)

# Crear un array de ceros
zeros_array = np.zeros(5)

# Crear un array de unos
ones_array = np.ones(5)

# Crear un array de números aleatorios
random_array = np.random.rand(5)

# %% [markdown]
# Un aspecto muy interesante de las listas en numpy es que permite devolver sublistas que cumplan una determinada condición.
#
# Por ejemplo, si de la lista `my_array` solo quiero quedarme con aquellos elementos que sean mayores a 50, deberé ejecutar el siguiente código.

# %%
my_array[my_array>50]
# Out:
# array([256, 100])

# %% [markdown]
# También podemos realizar diferentes operaciones estadísticas sobre una lista.

# %%
# Calcular la media
mean = np.mean(my_array)

# Calcular la desviación estándar
std_dev = np.std(my_array)

# Calcular el máximo y mínimo
max_value = np.max(my_array)
min_value = np.min(my_array)

# %% [markdown]
# La función `.where` es muy útil si queremos obtener los *índices* de los elementos de una lista que cumplan una determinada condición.

# %% [markdown]
# Esto nos permite, por ejemplo, asignar valores en un array en base a una condición.

# %%
my_array[np.where(my_array > 100)] = 0
print(my_array)
# Out:
# [  0 100  25  16   9   4]

# %% [markdown]
# En caso de que quisieramos ordenar una lista pero obteniendo el orden de los índices de sus elementos podemos invocar el métoco `.argsort`.

# %%
vals = np.array([2,3,1,4,5])
sort_index = np.argsort(vals)
sort_index
# Out:
# array([2, 0, 1, 3, 4])

# %% [markdown]
# Por último, con los métodos `.save` y `.load` podemos serializar listas.

# %%
# Guardar array en un archivo
np.save('my_array.npy', my_array)

# Cargar array desde un archivo
loaded_array = np.load('my_array.npy')

# %% [markdown]
# ### 2. Medición de tiempo de ejecución

# %% [markdown]
# A la hora de medir el tiempo de ejecución de un código fuente, es esencial diferenciar dos términos:
#
# - El **wall time** es el tiempo total transcurrido durante la medición y que por tanto podríamos medir con un cronómetro. Es la diferencia entre el tiempo en el que un programa terminó su ejecución y el tiempo en el que el programa comenzó. Pero es importante indica que dicho tiempo también **incluye el tiempo de espera para obtener recursos**.
#
# - El **CPU time** se refiere al tiempo que la CPU estuvo ocupada procesando las instrucciones del programa. Sin embargo, el tiempo empleado en esperar a que se completen otras tareas (como las operaciones de E/S) no se incluye en el tiempo de CPU asi como tampoco el tiempo de espera de recursos.
#
# La diferencia entre el *wall* y el *CPU time* puede deberse a la arquitectura de la máquina o a dependencias en tiempo real como, por ejemplo, a retrasos programados o a la espera de que los recursos del sistema estén disponibles.
#
# Por ejemplo, si para un programa obtenemos un *CPU time* de 0m0.2s y un *wall time* de 2m4s, significa que el programa estuvo activo durante 2 minutos y cuatro segundos. Sin embargo, el procesador del ordenador sólo empleó 0,2 segundos realizando cálculos para el programa.

# %% [markdown]
# En el entorno de ejecución con `Notebooks` podemos usar la primitiva `%time` que nos devolverá ambos tipos de tiempo como salida de la celda en la que se encuentre.

# %%
# %time

n=0
for i in range(100000):
  n += i
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# En otros entornos de ejecución, el módulo `time` proporciona funciones para trabajar con el tiempo.
#
# - Para medir el *wall time* podemos usar la función `.time`
# - Para medir el *cpu time* podemos usar la funcion `.process_time`
#
#
# Así, para medir ambos tiempos de un determinado código solo se tiene que llamar a ambas funciones antes y después de la funcionalidad a testear.

# %%
import time

start_time = time.time()
start_time_perf= time.process_time()
# Código que queremos medir.
n=0
for i in range(100000):
  n += i
time.sleep(3) #Entramos a dormir para forzar que el wall time sea claramente mayor al cpu time.
# Fin del código que queremos medir
end_time_time_perf= time.process_time()
end_time = time.time()

cpu_time= end_time_time_perf - start_time_perf
wall_time = end_time - start_time
print("CPU time:", cpu_time, "segundos")
print("Wall time:", wall_time, "segundos")
# Out:
# CPU time: 0.015625 segundos
# Wall time: 3.0317907333374023 segundos

# %% [markdown]
# ### 3. Paso de parámetros en Python
#
#
# Dependiendo del tipo de dato que enviemos a la función, podemos diferenciar dos comportamientos:
#
# - **Paso por valor**: Se crea una copia local de la variable dentro de la función.
# - **Paso por referencia**: Se maneja directamente la variable, los cambios realizados dentro de la función le afectarán también fuera.
# Tradicionalmente:
#
# Los tipos simples se pasan por valor: Enteros, flotantes, cadenas, lógicos...
#
# Los tipos compuestos se pasan por referencia: Listas, diccionarios, conjuntos...

# %% [markdown]
# #### Paso por valor

# %%
def doblar_valor(numero):
    numero *= 2

n = 10
doblar_valor(n)
print(n)
# Out:
# 10

# %% [markdown]
# Como vemos el valor de `n` no se modifica después de la llamada a la función.

# %% [markdown]
# #### Paso por referencia

# %%
def doblar_valores(numeros):
    for i,n in enumerate(numeros):
        numeros[i] *= 2

ns = [10,50,100]
doblar_valores(ns)
print(ns)
# Out:
# [20, 100, 200]

# %% [markdown]
# En este caso vemos que la lista `ns` sí que se modifica al hacer la llamada a la función `doblar_valores`.

# %% [markdown]
# Paso de parametros al programa main.

# %% [markdown]
# ### 4. Recursividad

# %% [markdown]
# **¿Qué es la recursividad?**
#
# La recursividad es un concepto de programación en el que una función se llama a sí misma para resolver un problema de manera iterativa.
#
# Es especialmente útil cuando el problema se puede dividir en casos más pequeños y similares al original.
#
# Un ejemplo muy sencillo de aplicación de la recursividad consiste en el cómputo del factorial de un número.

# %%
def factorial(n):
  if n == 0:
    return 1
  else:
    return n * factorial(n - 1)

print(factorial(5))
# Out:
# 120

# %% [markdown]
# Si añadimos un `print` al comienzo de la función podemos ver la secuencia encadenada de llamadas.

# %%
def factorial(n):
  print("Procesando el número ",n)
  if n == 0:
    print("Entro en el caso base")
    return 1
  else:
    return n * factorial(n - 1)

print("El valor del factorial es", factorial(5))
# Out:
# Procesando el número  5
# Procesando el número  4
# Procesando el número  3
# Procesando el número  2
# Procesando el número  1
# Procesando el número  0
# Entro en el caso base
# El valor del factorial es 120

# %% [markdown]
# A la hora de usar la recursividad debemos de tener en cuenta cómo se realiza el paso de parámetros a una función en Python que hemos visto en el punto 3.
#
# Por ejemplo, al pasarse las listas por referencia, podríamos implementar una función recursiva que vaya generando una lista incremental simplememente añadiendo un nuevo elemento que sea el último de la lista actual más  `1`.

# %%
def añadir_elemento(l):
  if len(l)==5:
    return l
  else:
    l.append(l[-1]+1)
    return añadir_elemento(l)

mi_lista=[1]
nueva_lista= añadir_elemento(mi_lista)
print(mi_lista)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### 5. Generación de `Docstrings`
#
# Cuando deseemos documentar nuestro código, ya sea una función, un método, una clase, un módulo o un paquete, lo haremos mediante un `docstring`.
#
# Para poder documentar nuestro código vamos a colocar, en la primera línea del cuerpo de la función, un comentario con triple comillas simples (""") con los siguientes puntos:
#
# - La primera línea debe poseer una breve descripción del funcionamiento del código. Las descripciones deben comenzar con mayúscula y finalizar con punto.
#
# - La segunda deberá ser un espacio en blanco, de tal forma que sea fácil distinguir entre la descripción y el resto del comentario.
#
# - La tercera línea deberá incluir una descripción más detallada de la funcionalidad del código, seguida por un espacio en blanco.
#
# - La cuarta línea deberá ser de nuevo un espacio en blanco.
#
# - Las siguientes líneas deben ser uno o más párrafos que describan lps parámetros de entrada de la función.
#
# - La última línda deberá ser el tipo de dato devuelvo por la función y una breve descripción del resultado.
#
# A continuación mostramos un ejemplo de `docstring` para una función sencilla que trata una función. ¿Sabrías decir lo que hace sin necesidad de ejecutar el código?

# %%
def sustituir_entre_indices(mi_cadena, viejo_caracter, nuevo_caracter, i, j):
    """
    Sustituye todas las ocurrencias del caracter 'viejo_caracter' por el caracter 'nuevo_caracter' en la cadena 'mi_cadena' entre los índices dados.

    Esta función toma una cadena de texto mi_cadena, dos caracteres 'viejo_caracter' y 'nuevo_caracter', y dos índices 'i' y 'j', y reemplaza
    todas las ocurrencias del caracter 'viejo_caracter' por el caracter 'nuevo_caracter' en la subcadena de mi_cadena delimitada por los índices 'i' y 'j'.

    Parámetros:
    mi_cadena (str): La cadena de texto en la que se realizará la sustitución.
    viejo_caracter (str): El caracter que se desea reemplazar.
    nuevo_caracter (str): El caracter con el que se reemplazará 'a'.
    i (int): El índice de inicio (inclusive) del rango donde se realizará la sustitución.
    j (int): El índice de fin (exclusivo) del rango donde se realizará la sustitución.

    Devuelve:
    str: La cadena 'mi_cadena' con todas las ocurrencias de 'nuevo_caracter' reemplazadas por 'b' entre los índices 'i' y 'j'.
    """
    parte_inicial= mi_cadena[:i]
    parte_reemplazada= mi_cadena[i:j].replace(viejo_caracter, nuevo_caracter)
    parte_final= mi_cadena[j:]
    return parte_inicial + parte_reemplazada + parte_final

# %% [markdown]
# Vamos a ejecutar dicha función para ver si se corresponde con lo que has deducido de leer su `docstring`.

# %%
cadena_original = "Hola mundo"
caracter_a = "o"
caracter_b = "x"
indice_inicio = 1
indice_fin = 5
resultado_sustitucion = sustituir_entre_indices(cadena_original, caracter_a, caracter_b, indice_inicio, indice_fin)
print("Resultado de la sustitución entre los índices", indice_inicio, "y", indice_fin, ":", resultado_sustitucion)
# Out:
# Resultado de la sustitución entre los índices 1 y 5 : Hxla mundo

# %% [markdown]
# ### 6. Visualización de datos
#
# En esta sección vamos a practicar con la librería `matplotlib` para poder visualizar datos de forma sencilla
#
# Visualización de regresion dados unos puntos.

# %% [markdown]
# #### 6.1 Librería `matplotlib`
#
# En primer lugar vamos a importar la librería

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Veamos un ejemplo muy simple usando dos arrays numpy. También puedes usar listas, pero lo más probable es que pases arrays de numpy o columnas de pandas (que en esencia también se comportan como arrays).

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# **Comandos básicos**
#
# Podemos crear un gráfico de líneas muy sencillo utilizando lo siguiente

# %%
plt.plot(x, y, 'r') # 'r' se refiere al color rojo
plt.xlabel('Título del eje X aquí')
plt.ylabel('Título del eje Y aquí')
plt.title('Título de la figura aquí')
plt.show()

# %% [markdown]
# Podemos crear también varios plots en un mismo canvas.

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %% [markdown]
# La idea principal al utilizar el método más formal de Orientación a Objetos es crear objetos de tipo `figure` y luego simplemente llamar a métodos o atributos de ese objeto. Este enfoque es más adecuado cuando se trata de un *canvas*  que tiene múltiples parcelas en él.
#
# Para empezar creamos una figura y añadir ejes a la misma:

# %%
# Creamos un Figure (canvas vacío)
fig = plt.figure()

# Añadimos un conjunto de ejes a la figura
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # izquierda, abajo, ancho y largo (rango entre 0 y 1)

# Imprimimos sobre dicho conjunto de ejes
axes.plot(x, y, '#007AFF', linestyle='dashed')
axes.set_xlabel('Etiqueta del eje X') #
axes.set_ylabel('Etiqueta del eje y')
axes.set_title('Titulo de la figura')
# Out:
# Text(0.5, 1.0, 'Titulo de la figura')

# %% [markdown]
# **Leyenda**
#
# Puede utilizar la palabra clave `label="label text` cuando se añadan gráficos u otros objetos a la figura y, a continuación, utilizar el método `legend` sin argumentos para añadir la leyenda a la figura:

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label=r"$x^2$")
ax.plot(x, x**3, label=r"$x^3$")
ax.legend()

# %% [markdown]
# **Guardar figuras**
#
# Matplotlib puede generar resultados de alta calidad en varios formatos, como PNG, JPG, EPS, SVG, PGF y PDF.
#
# Para guardar una figura en un archivo podemos utilizar el método `.savefig` de la clase `Figure`:

# %%
fig.savefig("filename.png")

# %% [markdown]
# **Tipos de gráficos especiales**
#
# Hay muchos tipos especiales de gráficos que podemos crear, como gráficos de barras, histogramas, gráficos de dispersión y muchos más. La mayoría de estos tipos de gráficos los crearemos usando seaborn, una librería de gráficos estadísticos para Python. Pero aquí hay algunos ejemplos de este tipo de gráficos:

# %%
plt.scatter(x,y);

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data, edgecolor='black', facecolor='#007AFF');

# %% [markdown]
# **Escala logarítimca**
#
# También es posible establecer una escala logarítmica para uno o ambos ejes. Esta funcionalidad es de hecho sólo una aplicación de un sistema de transformación más general en Matplotlib. Cada una de las escalas de los ejes se establece por separado utilizando los métodos `set_xscale` y `set_yscale` que aceptan un parámetro (con el valor "log" en este caso):

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))

axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_title("Escala normal")

axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Escala logaritmica (y)");

# %% [markdown]
# **Notación científica**
#
# Con números grandes en los ejes, a menudo es mejor utilizar la notación científica:

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(x, x**2, x, np.exp(x))
ax.set_title("notación científica")

ax.set_yticks([0, 50, 100, 150])

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax.yaxis.set_major_formatter(formatter)

# %% [markdown]
# **Rejilla**
#
# Con el método `grid` del objeto eje, podemos activar y desactivar las líneas de la cuadrícula. También podemos personalizar el aspecto de las líneas de la cuadrícula utilizando los mismos argumentos de palabra clave que la función `plot`:

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,3))

# rejilla por defecto
axes[0].plot(x, x**2, x, x**3, lw=2)
axes[0].grid(True)

# rejilla customizada
axes[1].plot(x, x**2, x, x**3, lw=2)
axes[1].grid(color='b', alpha=0.5, linestyle='dashed', linewidth=0.5)

# %% [markdown]
# **Imágenes en 3D**
#
# Para utilizar gráficos 3D en matplotlib, primero tenemos que crear una instancia de la clase `Axes3D`. Los ejes 3D se pueden añadir a un lienzo de matplotlib exactamente de la misma manera que los ejes 2D; o, más convenientemente, pasando un argumento `projection='3d'` a los métodos `add_axes` o `add_subplot`.

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5
def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

fig = plt.figure(figsize=(14,6))

# `ax` is a 3D-aware axis instance because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface plot con diferentes tipos de texturas.
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %% [markdown]
# #### 6.2 Librería `seaborn`
#
# **Plots de regresión**
#
# Seaborn tiene muchas capacidades incorporadas para los gráficos de regresión. En este sentido, `lmplot` permite mostrar modelos lineales
#
# Vamos a explorar cómo funciona:
#
# En primer lugar importamos la libreria

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# A continuación importamos el dataset `tips` proporcionado por `seaborn` con la información de las propinas proporcionadas por diferentes clientes en un restaurante

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm')

# %% [markdown]
# **Usando un grid**
#
# Podemos añadir más separación de variables mediante columnas y filas con el uso de una rejilla. Basta con indicarlo con los argumentos `col` o `row`:

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='coolwarm')

# %% [markdown]
# ### 7. Ejercicios

# %% [markdown]
# ##### Ejercicio 1 - Listas
#
# Dada la lista [6,7,8,9,10], obten una nueva lista que solo contenga los tres primeros números multiplicados por 4, es decir [24, 28, 32]. Debe de realizarse mediante list comprehension.

# %%
list = [6, 7, 8, 9, 10]
list = [x * 4 for x in list[:3]]
print(list)
# Out:
# [24, 28, 32]

# %% [markdown]
# Solución

# %% [markdown]
# #### Ejercicio 2 - Recursividad
#
# Implementa una función recursiva que genere una lista de longitud 5 en donde todos sus elementos sean el número 1, es decir [1,1,1,1,1].
#
# No te olvides de generar el `docstring` de dicha función.

# %%
def create_ones_list(lista):
  '''
  Genera una lista de longitud 5 donde todos sus elementos son el número 1.

  Se le entrega una lista en principio vacía en la que comprueba que tiene
  longitud 5 y hasta que no la tenga, añade un 1.
  '''
  if len(lista) == 5:
    return lista
  else:
    lista.append(1)
    return create_ones_list(lista)

lista = []
print(create_ones_list(lista))
# Out:
# [1, 1, 1, 1, 1]

# %% [markdown]
# Solución

# %% [markdown]
# #### Ejercicio 3 - Visualización de datos
#
# Asumiendo el siguiente conjunto de datos

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# - Crea un objeto `figure` llamado `fig` usando `plt.figure()`
# - Usa `add_axes` para añadir un eje al lienzo de la figura en [0,0,1,1]. Llama a este nuevo eje `ax`.
# - Muestra (x,y) en ese eje y establece las etiquetas y títulos par ala figura, eje x y eje y con los metodos `set_xlabel`, `set_ylabel` y `set_title`.

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, '#007AFF', linestyle=(5, (10, 3)))
ax.set_xlabel(r'Eje $x$')
ax.set_ylabel(r'Eje $y$')
ax.set_title('Figura Ejercicio 3')
# Out:
# Text(0.5, 1.0, 'Figura Ejercicio 3')

# %% [markdown]
# Solución

# %% [markdown]
# ### Referencias
#
# **Paso de parámetros**
# - [Hecktor Docs. Paso por valor y referencia. 2018](https://docs.hektorprofe.net/python/programacion-de-funciones/paso-por-valor-y-referencia/)
#
# **Docstrings**
# - [Eduardo Ismael. Cómo documentar tu código Python. 2021](https://pywombat.com/articles/docstring-python)
#
# **Visualizacion de datos**
# * http://www.matplotlib.org
# * https://github.com/matplotlib/matplotlib
# * http://matplotlib.org/gallery.html
# * http://www.loria.fr/~rougier/teaching/matplotlib
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html

# %% [markdown]
# ¡Esto es todo amigos!
